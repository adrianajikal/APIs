# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df.head()
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      28489        Município          Rio de Janeiro   3304557  RJ
# 1      60633        Município             Nova Iguaçu   3303500  RJ
# 2       5734        Município          Rio de Janeiro   3304557  RJ
# 3      13784        Município  Santo Antônio de Pádua   3304706  RJ
# 4      13574        Município          Rio de Janeiro   3304557  RJ
#
#                 num_pvl                          status          num_processo  \
# 0  PVL02.000606/2018-62  Arquivado por decurso de prazo  17944.104407/2018-95
# 1  PVL02.005341/2022-75                        Deferido  17944.102616/2022-81
# 2                  None                        Deferido  17944.000185/2010-85
# 3                  None                        Deferido  19405.000084/2002-27
# 4                  None                        Deferido  19405.000028/2006-16
#
#          data_protocolo                tipo_operacao  \
# ...

# %%
# 2) Seu código aqui
df.status.value_counts()
# Out:
# Deferido                                                 96
# Arquivado                                                53
# Regularizado                                             26
# Arquivado por decurso de prazo                           24
# Deferido (PVL-IF)                                        19
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           2
# Em análise                                                1
# Em retificação pelo credor                                1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df['ano_status'] = df['data_status'].str.split('/').str[-1]
df.head()
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      28489        Município          Rio de Janeiro   3304557  RJ
# 1      60633        Município             Nova Iguaçu   3303500  RJ
# 2       5734        Município          Rio de Janeiro   3304557  RJ
# 3      13784        Município  Santo Antônio de Pádua   3304706  RJ
# 4      13574        Município          Rio de Janeiro   3304557  RJ
#
#                 num_pvl                          status          num_processo  \
# 0  PVL02.000606/2018-62  Arquivado por decurso de prazo  17944.104407/2018-95
# 1  PVL02.005341/2022-75                        Deferido  17944.102616/2022-81
# 2                  None                        Deferido  17944.000185/2010-85
# 3                  None                        Deferido  19405.000084/2002-27
# 4                  None                        Deferido  19405.000028/2006-16
#
#          data_protocolo                tipo_operacao  \
# ...

# %%
df.ano_status.value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2020    15
# 2013    15
# 2012    13
# 2023    11
# 2022    11
# 2011    10
# 2009     9
# 2015     8
# 2017     5
# 2021     5
# 2016     4
# 2006     4
# 2002     4
# 2018     4
# 2004     1
# 2003     1
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

def consultar_dados(uf, tipo_interessado):
    url_dados = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    try: 
        r = requests.get(url_dados)
        r.status_code
        data_json = r.json()
        df = pd.DataFrame(data_json['items'])
        return df
    except:
        print('Erro na consulta: r.status_code')
        return None

# %%
# 2) Seu código aqui - Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?
uf = 'MG'
tipo_interessado = 'Estado'

dados_mg = consultar_dados(uf, tipo_interessado)
dados_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      13549           Estado  Minas Gerais        31  MG    None
# 1      13641           Estado  Minas Gerais        31  MG    None
# 2      12286           Estado  Minas Gerais        31  MG    None
# 3      11696           Estado  Minas Gerais        31  MG    None
# 4      13441           Estado  Minas Gerais        31  MG    None
#
#                status          num_processo        data_protocolo  \
# 0            Deferido  19405.000023/2006-93  2006-05-19T03:00:00Z
# 1            Deferido  19405.000042/2004-58  2004-11-26T02:00:00Z
# 2           Arquivado  17944.001650/2008-81  2008-12-31T02:00:00Z
# 3  Arquivado a pedido  17944.001504/2014-01  2015-04-13T03:00:00Z
# 4            Deferido  19405.000001/2005-42  2005-08-16T03:00:00Z
#
#                                        tipo_operacao         finalidade  \
# 0                        Operação contratual interna     Infraestrutura
# ...

# %%
dados_mg.status.value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui - Qual é o município da Bahia com mais solicitações deferidas?
uf = 'BA'
tipo_interessado = 'Munic%C3%ADpio'

dados_ba = consultar_dados(uf, tipo_interessado)
dados_ba.head()
# Out:
#    id_pleito tipo_interessado       interessado  cod_ibge  uf  \
# 0      25706        Município   Coronel João Sá   2909208  BA
# 1      22790        Município            Itiúba   2917003  BA
# 2      27329        Município         Pindobaçu   2924603  BA
# 3      30294        Município      Castro Alves   2907301  BA
# 4      45802        Município  Feira de Santana   2910800  BA
#
#                 num_pvl                          status          num_processo  \
# 0  PVL02.001443/2017-54                    Regularizado  17944.100852/2017-03
# 1  00000.000000/2032-86  Arquivado por decurso de prazo  17944.000729/2016-02
# 2  PVL02.002661/2017-14  Arquivado por decurso de prazo  17944.100216/2018-54
# 3  PVL02.002725/2018-50               Deferido (PVL-IF)                  None
# 4  PVL02.001922/2021-57              Arquivado a pedido  17944.102861/2021-15
#
#          data_protocolo                tipo_operacao  \
# 0  2017-11-13T19:20:24Z  Operação contratual interna
# ...

# %%
dados_ba[dados_ba['status'] == 'Deferido']['interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães    15
# Vitória da Conquista      11
# Camaçari                  10
# Barreiras                 10
# Lauro de Freitas          10
#                           ..
# Santana                    1
# São Felipe                 1
# Cardeal da Silva           1
# Cafarnaum                  1
# Itapicuru                  1
# Name: interessado, Length: 180, dtype: int64

# %%
# 4) Seu código aqui - Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'
uf = 'BA'
tipo_interessado = 'Estado'

dados_ba = consultar_dados(uf, tipo_interessado)
dados_ba.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0      18511           Estado       Bahia        29  BA    None
# 1      18543           Estado       Bahia        29  BA    None
# 2      18368           Estado       Bahia        29  BA    None
# 3      18389           Estado       Bahia        29  BA    None
# 4      12327           Estado       Bahia        29  BA    None
#
#                                               status          num_processo  \
# 0                                           Deferido  19407.000039/2002-52
# 1                                           Deferido  19407.000047/2002-07
# 2                                           Deferido  19407.000008/2005-44
# 3                                           Deferido  19407.000013/2002-12
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001659/2008-91
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
dados_ba.to_csv('dataframe_dados_bahia_estados.csv')
